# %%
import pandas as pd
import numpy as np
# Relative path from notebooks/ to data/
file_path = "../data/google_stock_data.xlsx"

# Read the Excel file
price = pd.read_excel(file_path)

# Round all numerical columns to 2 decimal places
price = price.round(2)

# Rename columns
price.rename(columns={'Date': 'date', 'Close_GOOG': 'close', 'High_GOOG': 'high'
                   ,'Low_GOOG': 'low', 'Open_GOOG': 'open'
                   ,'Volume_GOOG': 'volume'}, inplace=True)

# %% [markdown]
# 1. Convert the date column to datetime and verify the dtype.

# %%
price['date'] = pd.to_datetime(price['date'])
print(price['date'].dtype)
# Out:
# datetime64[ns]

# %% [markdown]
# 2. Create the following columns:
#
# - year
#
# - month
#
# - day
#
# - weekday (Monday, Tuesday, etc.)

# %%
price['year'] = price['date'].dt.year
price['month'] = price['date'].dt.month
price['day'] = price['date'].dt.day
price['weekday'] = price['date'].dt.weekday
price
# Out:
#            date   close    high     low    open    volume  year  month  day  \
# 0    2020-01-02   67.90   67.94   66.62   66.62  28132000  2020      1    2
# 1    2020-01-03   67.57   68.16   66.82   66.93  23728000  2020      1    3
# 2    2020-01-06   69.24   69.35   67.04   67.04  34646000  2020      1    6
# 3    2020-01-07   69.19   69.67   69.05   69.42  30054000  2020      1    7
# 4    2020-01-08   69.74   70.10   69.07   69.13  30560000  2020      1    8
# ...         ...     ...     ...     ...     ...       ...   ...    ...  ...
# 1253 2024-12-24  196.93  197.03  194.57  195.54   6809800  2024     12   24
# 1254 2024-12-26  196.46  197.52  195.24  196.10   7907900  2024     12   26
# 1255 2024-12-27  193.41  196.16  191.35  195.84  14693000  2024     12   27
# 1256 2024-12-30  192.07  193.15  189.75  190.25  12209500  2024     12   30
# 1257 2024-12-31  189.83  192.63  188.97  191.82  14355200  2024     12   31
#
#       weekday
# 0           3
# 1           4
# 2           0
# 3           1
# 4           2
# ...       ...
# 1253        1
# 1254        3
# 1255        4
# 1256        0
# 1257        1
#
# [1258 rows x 10 columns]

# %% [markdown]
# 3. Select all rows after January 15, 2024.

# %%
price.loc[price['date'] > '2024-01-15']
# Out:
#            date   close    high     low    open    volume  year  month  day  \
# 1015 2024-01-16  143.10  144.85  142.08  142.46  19198900  2024      1   16
# 1016 2024-01-17  141.92  142.44  139.55  141.94  17884500  2024      1   17
# 1017 2024-01-18  144.00  144.60  142.38  142.47  18876800  2024      1   18
# 1018 2024-01-19  146.96  147.03  144.81  145.31  27181000  2024      1   19
# 1019 2024-01-22  146.71  149.00  146.58  147.70  21829200  2024      1   22
# ...         ...     ...     ...     ...     ...       ...   ...    ...  ...
# 1253 2024-12-24  196.93  197.03  194.57  195.54   6809800  2024     12   24
# 1254 2024-12-26  196.46  197.52  195.24  196.10   7907900  2024     12   26
# 1255 2024-12-27  193.41  196.16  191.35  195.84  14693000  2024     12   27
# 1256 2024-12-30  192.07  193.15  189.75  190.25  12209500  2024     12   30
# 1257 2024-12-31  189.83  192.63  188.97  191.82  14355200  2024     12   31
#
#       weekday
# 1015        1
# 1016        2
# 1017        3
# 1018        4
# 1019        0
# ...       ...
# 1253        1
# 1254        3
# 1255        4
# 1256        0
# 1257        1
#
# [243 rows x 10 columns]

# %% [markdown]
# 4. Set date as the DataFrame index.
#
# Then:
#
# - Check the index type
#
# - Confirm it’s sorted

# %%
price.set_index('date', inplace= True)
price
# Out:
#              close    high     low    open    volume  year  month  day  \
# date
# 2020-01-02   67.90   67.94   66.62   66.62  28132000  2020      1    2
# 2020-01-03   67.57   68.16   66.82   66.93  23728000  2020      1    3
# 2020-01-06   69.24   69.35   67.04   67.04  34646000  2020      1    6
# 2020-01-07   69.19   69.67   69.05   69.42  30054000  2020      1    7
# 2020-01-08   69.74   70.10   69.07   69.13  30560000  2020      1    8
# ...            ...     ...     ...     ...       ...   ...    ...  ...
# 2024-12-24  196.93  197.03  194.57  195.54   6809800  2024     12   24
# 2024-12-26  196.46  197.52  195.24  196.10   7907900  2024     12   26
# 2024-12-27  193.41  196.16  191.35  195.84  14693000  2024     12   27
# 2024-12-30  192.07  193.15  189.75  190.25  12209500  2024     12   30
# 2024-12-31  189.83  192.63  188.97  191.82  14355200  2024     12   31
#
#             weekday
# date
# 2020-01-02        3
# 2020-01-03        4
# 2020-01-06        0
# 2020-01-07        1
# 2020-01-08        2
# ...             ...
# 2024-12-24        1
# 2024-12-26        3
# 2024-12-27        4
# 2024-12-30        0
# 2024-12-31        1
#
# [1258 rows x 9 columns]

# %%
print(price.index.dtype)
print(price.index.is_monotonic_increasing)
# Out:
# datetime64[ns]
# True

# %% [markdown]
# 5. Resample data to monthly frequency and compute:
#
# - Mean close
#
# - Total volume

# %%
price['average_monthly_close']= price['close'].resample('M').transform('mean')
price['total_monthly_volume']= price['volume'].resample('M').transform('sum')
price
# Out:
#              close    high     low    open    volume  year  month  day  \
# date
# 2020-01-02   67.90   67.94   66.62   66.62  28132000  2020      1    2
# 2020-01-03   67.57   68.16   66.82   66.93  23728000  2020      1    3
# 2020-01-06   69.24   69.35   67.04   67.04  34646000  2020      1    6
# 2020-01-07   69.19   69.67   69.05   69.42  30054000  2020      1    7
# 2020-01-08   69.74   70.10   69.07   69.13  30560000  2020      1    8
# ...            ...     ...     ...     ...       ...   ...    ...  ...
# 2024-12-24  196.93  197.03  194.57  195.54   6809800  2024     12   24
# 2024-12-26  196.46  197.52  195.24  196.10   7907900  2024     12   26
# 2024-12-27  193.41  196.16  191.35  195.84  14693000  2024     12   27
# 2024-12-30  192.07  193.15  189.75  190.25  12209500  2024     12   30
# 2024-12-31  189.83  192.63  188.97  191.82  14355200  2024     12   31
#
#             weekday  average_monthly_close  total_monthly_volume
# date
# 2020-01-02        3              71.344762             673832000
# 2020-01-03        4              71.344762             673832000
# 2020-01-06        0              71.344762             673832000
# 2020-01-07        1              71.344762             673832000
# 2020-01-08        2              71.344762             673832000
# ...             ...                    ...                   ...
# 2024-12-24        1             187.639048             447499100
# 2024-12-26        3             187.639048             447499100
# 2024-12-27        4             187.639048             447499100
# 2024-12-30        0             187.639048             447499100
# 2024-12-31        1             187.639048             447499100
#
# [1258 rows x 11 columns]

# %% [markdown]
# 6. Resample to weekly data and compute:
#
# - Last close price of each week
#
# - Max high of each week

# %%
price['weekly_last_close'] = price['close'].resample('W').transform('last')
price['weekly_max_high'] = price['high'].resample('W').transform('max')
price
# Out:
#              close    high     low    open    volume  year  month  day  \
# date
# 2020-01-02   67.90   67.94   66.62   66.62  28132000  2020      1    2
# 2020-01-03   67.57   68.16   66.82   66.93  23728000  2020      1    3
# 2020-01-06   69.24   69.35   67.04   67.04  34646000  2020      1    6
# 2020-01-07   69.19   69.67   69.05   69.42  30054000  2020      1    7
# 2020-01-08   69.74   70.10   69.07   69.13  30560000  2020      1    8
# ...            ...     ...     ...     ...       ...   ...    ...  ...
# 2024-12-24  196.93  197.03  194.57  195.54   6809800  2024     12   24
# 2024-12-26  196.46  197.52  195.24  196.10   7907900  2024     12   26
# 2024-12-27  193.41  196.16  191.35  195.84  14693000  2024     12   27
# 2024-12-30  192.07  193.15  189.75  190.25  12209500  2024     12   30
# 2024-12-31  189.83  192.63  188.97  191.82  14355200  2024     12   31
#
#             weekday  average_monthly_close  total_monthly_volume  \
# date
# 2020-01-02        3              71.344762             673832000
# 2020-01-03        4              71.344762             673832000
# 2020-01-06        0              71.344762             673832000
# 2020-01-07        1              71.344762             673832000
# 2020-01-08        2              71.344762             673832000
# ...             ...                    ...                   ...
# 2024-12-24        1             187.639048             447499100
# 2024-12-26        3             187.639048             447499100
# 2024-12-27        4             187.639048             447499100
# 2024-12-30        0             187.639048             447499100
# 2024-12-31        1             187.639048             447499100
#
#             weekly_last_close  weekly_max_high
# date
# 2020-01-02              67.57            68.16
# 2020-01-03              67.57            68.16
# 2020-01-06              71.00            71.26
# 2020-01-07              71.00            71.26
# 2020-01-08              71.00            71.26
# ...                       ...              ...
# 2024-12-24             193.41           197.52
# 2024-12-26             193.41           197.52
# 2024-12-27             193.41           197.52
# 2024-12-30             189.83           193.15
# 2024-12-31             189.83           193.15
#
# [1258 rows x 13 columns]

# %% [markdown]
# 7. What is the difference between:
#
# - 7-day rolling average of close
#
# - Weekly resampled average close
#
#
# The 7 day rolling average take 7 days moving window and calculates average. The calculated average could different between any given adjacent dates. In contrast, weekly resampled average is common for all the dates that were resampled to calculate the average.

# %% [markdown]
# 8. Compute a 7-day rolling average of close.
#
# - Does this reduce the number of rows?
#
# - Why or why not?

# %%
price['7day_rolling_avg']= price['close'].rolling(7).mean()
price
# Out:
#              close    high     low    open    volume  year  month  day  \
# date
# 2020-01-02   67.90   67.94   66.62   66.62  28132000  2020      1    2
# 2020-01-03   67.57   68.16   66.82   66.93  23728000  2020      1    3
# 2020-01-06   69.24   69.35   67.04   67.04  34646000  2020      1    6
# 2020-01-07   69.19   69.67   69.05   69.42  30054000  2020      1    7
# 2020-01-08   69.74   70.10   69.07   69.13  30560000  2020      1    8
# ...            ...     ...     ...     ...       ...   ...    ...  ...
# 2024-12-24  196.93  197.03  194.57  195.54   6809800  2024     12   24
# 2024-12-26  196.46  197.52  195.24  196.10   7907900  2024     12   26
# 2024-12-27  193.41  196.16  191.35  195.84  14693000  2024     12   27
# 2024-12-30  192.07  193.15  189.75  190.25  12209500  2024     12   30
# 2024-12-31  189.83  192.63  188.97  191.82  14355200  2024     12   31
#
#             weekday  average_monthly_close  total_monthly_volume  \
# date
# 2020-01-02        3              71.344762             673832000
# 2020-01-03        4              71.344762             673832000
# 2020-01-06        0              71.344762             673832000
# 2020-01-07        1              71.344762             673832000
# 2020-01-08        2              71.344762             673832000
# ...             ...                    ...                   ...
# 2024-12-24        1             187.639048             447499100
# 2024-12-26        3             187.639048             447499100
# 2024-12-27        4             187.639048             447499100
# 2024-12-30        0             187.639048             447499100
# 2024-12-31        1             187.639048             447499100
#
#             weekly_last_close  weekly_max_high  7day_rolling_avg
# date
# 2020-01-02              67.57            68.16               NaN
# 2020-01-03              67.57            68.16               NaN
# 2020-01-06              71.00            71.26               NaN
# 2020-01-07              71.00            71.26               NaN
# 2020-01-08              71.00            71.26               NaN
# ...                       ...              ...               ...
# 2024-12-24             193.41           197.52        193.894286
# 2024-12-26             193.41           197.52        193.742857
# 2024-12-27             193.41           197.52        193.304286
# 2024-12-30             189.83           193.15        193.665714
# 2024-12-31             189.83           193.15        193.771429
#
# [1258 rows x 14 columns]

# %% [markdown]
# This does not reduce the number of rows since the seven day window is moving across dates taking one by one over time. the 7 day rolling average is calculated for every day using close values of that day and last 6 days.

# %% [markdown]
# 9. Using resampled data:
#
# - Find the month with the highest total volume
#
# - Return the month and volume

# %%
price['total_monthly_volume'].max()
price.loc[price['total_monthly_volume'].idxmax(), 'month']
# Out:
# 3

# %% [markdown]
# 10. You are given daily stock data. How would you compute monthly returns?
#
# No full code required — outline the steps.
#
# First the date column of the dataframe will be set as the index. then the last close value of each month is selected. Then a new column will be calculated by subtracting the last close of the previous month from the last close of the current month.
#
# Below is the code.

# %%
monthly_returns_df = price['close'].resample('M').last().to_frame()
monthly_returns_df['month'] = monthly_returns_df.index.month
monthly_returns_df['monthly_return'] = monthly_returns_df['close'] - monthly_returns_df['close'].shift(1)
monthly_returns_df
# Out:
#              close  month  monthly_return
# date
# 2020-01-31   71.22      1             NaN
# 2020-02-29   66.51      2           -4.71
# 2020-03-31   57.75      3           -8.76
# 2020-04-30   66.97      4            9.22
# 2020-05-31   70.96      5            3.99
# 2020-06-30   70.20      6           -0.76
# 2020-07-31   73.64      7            3.44
# 2020-08-31   81.15      8            7.51
# 2020-09-30   72.98      9           -8.17
# 2020-10-31   80.50     10            7.52
# 2020-11-30   87.44     11            6.94
# 2020-12-31   87.00     12           -0.44
# 2021-01-31   91.16      1            4.16
# 2021-02-28  101.15      2            9.99
# 2021-03-31  102.73      3            1.58
# 2021-04-30  119.69      4           16.96
# 2021-05-31  119.76      5            0.07
# 2021-06-30  124.46      6            4.70
# 2021-07-31  134.30      7            9.84
# 2021-08-31  144.47      8           10.17
# 2021-09-30  132.36      9          -12.11
# 2021-10-31  147.26     10           14.90
# 2021-11-30  141.48     11           -5.78
# 2021-12-31  143.70     12            2.22
# 2022-01-31  134.78      1           -8.92
# 2022-02-28  133.97      2           -0.81
# 2022-03-31  138.70      3            4.73
# 2022-04-30  114.19      4          -24.51
# 2022-05-31  113.26      5           -0.93
# 2022-06-30  108.63      6           -4.63
# 2022-07-31  115.85      7            7.22
# 2022-08-31  108.41      8           -7.44
# 2022-09-30   95.50      9          -12.91
# 2022-10-31   94.02     10           -1.48
# 2022-11-30  100.76     11            6.74
# 2022-12-31   88.13     12          -12.63
# 2023-01-31   99.19      1           11.06
# 2023-02-28   89.69      2           -9.50
# 2023-03-31  103.29      3           13.60
# 2023-04-30  107.48      4            4.19
# 2023-05-31  122.53      5           15.05
# 2023-06-30  120.15      6           -2.38
# 2023-07-31  132.21      7           12.06
# 2023-08-31  136.42      8            4.21
# 2023-09-30  130.95      9           -5.47
# 2023-10-31  124.45     10           -6.50
# 2023-11-30  133.01     11            8.56
# 2023-12-31  139.97     12            6.96
# 2024-01-31  140.84      1            0.87
# 2024-02-29  138.83      2           -2.01
# 2024-03-31  151.23      3           12.40
# 2024-04-30  163.52      4           12.29
# 2024-05-31  172.78      5            9.26
# 2024-06-30  182.38      6            9.60
# 2024-07-31  172.17      7          -10.21
# 2024-08-31  164.17      8           -8.00
# 2024-09-30  166.46      9            2.29
# 2024-10-31  171.94     10            5.48
# 2024-11-30  169.75     11           -2.19
# 2024-12-31  189.83     12           20.08
